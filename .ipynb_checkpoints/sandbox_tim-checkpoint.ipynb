# %% [markdown]
# # Twitter Stance Detection
# W266 - NLP
# Alex Dessouky & Tim Spittle

# %% [markdown]
# NOTES to myself:
# * why is classification report not outputting the micro, macro, weighted avgs?
# * we have a class weighting problem
# * getting different f1 scores if I call f1 directly vs classification report

# %% [markdown]
# ## 1 - Load Packages & Data

# %%
# Data objects
import pandas as pd
import numpy as np
from scipy.sparse import csr_matrix, hstack

# Text Manipulation
import re
import string

# Timing
import time

# Tensor Flow
# !pip install "tensorflow>=2.0.0"
# !pip install --upgrade tensorflow-hub
import tensorflow as tf
import tensorflow_hub as hub

# Feature Extraction
from sklearn.feature_extraction.text import CountVectorizer
elmo = hub.Module("https://tfhub.dev/google/elmo/2", trainable=True)

# Models
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression

# Metrics
from sklearn import metrics #f1_score, classification_report, confusion_matrix, roc_auc_score

# Plots
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#load training data
twitter_train = pd.read_excel('./StanceDataset/train.xlsx')
twitter_train.head()
# Out:
#                                                Tweet           Target  \
# 0  @tedcruz And, #HandOverTheServer she wiped cle...  Hillary Clinton
# 1  Hillary is our best choice if we truly want to...  Hillary Clinton
# 2  @TheView I think our country is ready for a fe...  Hillary Clinton
# 3  I just gave an unhealthy amount of my hard-ear...  Hillary Clinton
# 4  @PortiaABoulger Thank you for adding me to you...  Hillary Clinton
#
#     Stance                                    Opinion Towards Sentiment
# 0  AGAINST  1.  The tweet explicitly expresses opinion abo...       neg
# 1    FAVOR  1.  The tweet explicitly expresses opinion abo...       pos
# 2  AGAINST  1.  The tweet explicitly expresses opinion abo...       neg
# 3  AGAINST  1.  The tweet explicitly expresses opinion abo...       neg
# 4     NONE  3.  The tweet is not explicitly expressing opi...       pos

# %%
#load test data
twitter_test = pd.read_excel('./StanceDataset/test.xlsx')
twitter_test.head()
# Out:
#                                                Tweet   Target   Stance  \
# 0  He who exalts himself shall      be humbled; a...  Atheism  AGAINST
# 1  RT @prayerbullets: I remove Nehushtan -previou...  Atheism  AGAINST
# 2  @Brainman365 @heidtjj @BenjaminLives I have so...  Atheism  AGAINST
# 3  #God is utterly powerless without Human interv...  Atheism  AGAINST
# 4  @David_Cameron   Miracles of #Multiculturalism...  Atheism  AGAINST
#
#                                      Opinion Towards Sentiment
# 0  1.  The tweet explicitly expresses opinion abo...       pos
# 1  1.  The tweet explicitly expresses opinion abo...     other
# 2  1.  The tweet explicitly expresses opinion abo...       pos
# 3  1.  The tweet explicitly expresses opinion abo...       neg
# 4  2. The tweet does NOT expresses opinion about ...       neg

# %% [markdown]
# ## 2 - Pre-process Data

# %%
# Example tweet
tweet_example = twitter_train['Tweet'][0]
print(tweet_example)
# Out:
# @tedcruz And, #HandOverTheServer she wiped clean + 30k deleted emails, explains dereliction of duty/lies re #Benghazi,etc #tcot

# %%
def preprocess_tweets(x):
    
    # Remove punctuation EXCEPT for hashtags (#) and handles (@)
    exclude_punc = [punc for punc in string.punctuation if punc not in ['#', '@']]
    x_nopunc = ''.join(ch for ch in x if ch not in exclude_punc)

    # lower case
    x_lower = x_nopunc.lower()
    
    # Replace digits with DIGIT
    x_digits = re.sub("\d+", "DIGIT", x_lower)
    
    return x_digits

# %%
preprocess_tweets(tweet_example)
# Out:
# '@tedcruz and #handovertheserver she wiped clean  DIGITk deleted emails explains dereliction of dutylies re #benghazietc #tcot'

# %% [markdown]
# ## 3 - Models

# %% [markdown]
# ### Prep Output Functions

# %%
def confusion_plot(confusion_matrix, target_names):
    # Plot confusion matrix (via imshow)
    plt.imshow(confusion_matrix, interpolation = "nearest", cmap = plt.cm.Blues)
    plt.title("Confusion matrix")
    plt.colorbar()
    tick_marks = np.arange(len(target_names))
    plt.xticks(tick_marks, target_names)
    plt.yticks(tick_marks, target_names)
    plt.tight_layout()

    # Loop through each value of the matrix to add data labels
    width, height = confusion_matrix.shape
    for x in range(width):
        for y in range(height):
            plt.annotate(str(confusion_matrix[x][y]), xy = (y, x), 
                        horizontalalignment = "center",
                        verticalalignment = "center")
    plt.ylabel("True label")
    plt.xlabel("Predicted label")
    
# Histograms of predicted probabilities
def class_prob_breakdown(model_results):
    plt.figure(figsize=(20, 10))

    plt.subplot(2,3,1)
    plt.title("Against")
    plt.hist([item[0] for item in model_results['test_predict_proba']])

    plt.subplot(2,3,2)
    plt.title("None")
    plt.hist([item[1] for item in model_results['test_predict_proba']])

    plt.subplot(2,3,3)
    plt.title("Favor")
    plt.hist([item[2] for item in model_results['test_predict_proba']])

    plt.subplot(2,3,4)
    plt.title("Against")
    sns.distplot([item[0] for item in model_results['test_predict_proba'][model_results['test_true_labels']==0]], 
                 hist = False, label = "True Against")
    sns.distplot([item[0] for item in model_results['test_predict_proba'][model_results['test_true_labels']==1]], 
                 hist = False, label = "True None")
    sns.distplot([item[0] for item in model_results['test_predict_proba'][model_results['test_true_labels']==2]], 
                 hist = False, label = "True Favor")

    plt.subplot(2,3,5)
    plt.title("None")
    sns.distplot([item[1] for item in model_results['test_predict_proba'][model_results['test_true_labels']==0]], 
                 hist = False, label = "True Against")
    sns.distplot([item[1] for item in model_results['test_predict_proba'][model_results['test_true_labels']==1]], 
                 hist = False, label = "True None")
    sns.distplot([item[1] for item in model_results['test_predict_proba'][model_results['test_true_labels']==2]], 
                 hist = False, label = "True Favor")
    
    plt.subplot(2,3,6)
    plt.title("Favor")
    sns.distplot([item[2] for item in model_results['test_predict_proba'][model_results['test_true_labels']==0]], 
                 hist = False, label = "True Against")
    sns.distplot([item[2] for item in model_results['test_predict_proba'][model_results['test_true_labels']==1]], 
                 hist = False, label = "True None")
    sns.distplot([item[2] for item in model_results['test_predict_proba'][model_results['test_true_labels']==2]], 
                 hist = False, label = "True Favor")

    plt.show()
    
def standard_output(model_results):
    # F1
    f1 = metrics.f1_score(y_true = model_results['test_true_labels'], 
                          y_pred = model_results['test_predict'], 
                          average = 'macro')
    print("F1 Score: " + str(f1))
    # Class Weights
    plt.subplot(1,2,1)
    model_results['train_names'].value_counts().plot(kind='bar', title = "Class Distribution - Train")
    plt.subplot(1,2,2)
    model_results['test_true_names'].value_counts().plot(kind='bar', title = "Class Distribution - Test")
    # Classification Report
    print(metrics.classification_report(y_true = model_results['test_true_labels'], 
                                        y_pred = model_results['test_predict'],
                                        target_names = ['Against', 'None', 'Favor']))
    # Confusion Matrix
    plt.figure(figsize=(15, 5))
    plt.subplot(1,2,1)
    confusion_plot(confusion_matrix = metrics.confusion_matrix(y_true = model_results['test_true_labels'], 
                                                               y_pred = model_results['test_predict']), 
                   target_names = ['Against', 'None', 'Favor'])
    # Class probability breakdown
    class_prob_breakdown(model_results = model_results)

# %% [markdown]
# ### Baseline (ZeroR)

# %%
def baseline_stance(train, test, topic_in):
    # Subset data to topic being tested
    train_topic = train[train['Target'] == topic_in]
    test_topic = test[test['Target'] == topic_in]
    
    #### TARGET ####
    # Convert stance to labels for feeding sklearn SVM
    train_stance_labels = np.array(train_topic['Stance'].apply(lambda x: 
                                                               2 if x == "FAVOR" else 
                                                               (1 if x == "NONE" else 0)))
    test_stance_labels = np.array(test_topic['Stance'].apply(lambda x: 
                                                             2 if x == "FAVOR" else 
                                                             (1 if x == "NONE" else 0)))
    
    #### MODEL ####
    print(topic_in)
    # Majority Class
    majority_class = Counter(train_stance_labels_tim).most_common(1)[0][0]
    
    # Prediction
    # Repeat majority class n times
    test_predict = [majority_class] * len(test_stance_labels)
    # Tuple of 3 index the majority class = 1
    majority_probs = [1 if i == majority_class else 0 for i in range(3)]
    test_predict_proba = []
    for i in range(len(test_stance_labels)):
        test_predict_proba.append(majority_probs)
    
    # Results
    results_dict = {}
    results_dict['model'] = "None"
    results_dict['full_feature_list'] = "None"
    results_dict['train_labels'] = train_stance_labels
    results_dict['train_names'] = train_topic['Stance']
    results_dict['test_true_labels'] = test_stance_labels
    results_dict['test_true_names'] = test_topic['Stance']
    results_dict['test_predict'] = test_predict
    results_dict['test_predict_proba'] = np.array(test_predict_proba)
    results_dict['test_predict_proba_true'] = [item[test_stance_labels[i]] for i, item in enumerate(test_predict_proba)]
    
    return results_dict

# %%
atheism_baseline = baseline_stance(train = twitter_train, 
                                   test = twitter_test, 
                                   topic_in = 'Atheism')
standard_output(model_results = atheism_baseline)
# Out:
# Atheism
# F1 Score: 0.28070175438596495
#              precision    recall  f1-score   support
#
#     Against       0.73      1.00      0.84       160
#        None       0.00      0.00      0.00        28
#       Favor       0.00      0.00      0.00        32
#
# avg / total       0.53      0.73      0.61       220
# /home/timspittle/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/timspittle/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/timspittle/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /home/timspittle/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /home/timspittle/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# /home/timspittle/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   # This branch is needed for reductions like any which don't

# %% [markdown]
# ### SVM

# %%
def svm_stance(train, test, topic_in):
    # Subset data to topic being tested
    train_topic = train[train['Target'] == topic_in]
    test_topic = test[test['Target'] == topic_in]
    
    #### FEATURES ####
    # Extract tweets
    tweets_train = train_topic['Tweet']
    tweets_test = test_topic['Tweet']

    # Pre-process tweets
    preprocess_train = tweets_train.apply(lambda x: preprocess_tweets(x))
    preprocess_test = tweets_test.apply(lambda x: preprocess_tweets(x))
    
    # Convert training data to sparse matrix 
    # n-gram WORDS
    word_grams = CountVectorizer(ngram_range = (1,3))
    train_nwords = word_grams.fit_transform(preprocess_train)
    test_nwords = word_grams.transform(preprocess_test)
    word_grams_feature_list = word_grams.get_feature_names()
    # n-gram CHARS
    char_grams = CountVectorizer(ngram_range = (2,5), analyzer = 'char')
    train_nchars = char_grams.fit_transform(preprocess_train)
    test_nchars = char_grams.transform(preprocess_test)
    char_grams_feature_list = char_grams.get_feature_names()
    
    # Stack the features
    train_grams = hstack((train_nwords, train_nchars))
    test_grams = hstack((test_nwords, test_nchars))
    full_feature_list = word_grams_feature_list + char_grams_feature_list
       
    #### TARGET ####
    # Convert stance to labels for feeding sklearn SVM
    train_stance_labels = np.array(train_topic['Stance'].apply(lambda x: 
                                                               2 if x == "FAVOR" else 
                                                               (1 if x == "NONE" else 0)))
    test_stance_labels = np.array(test_topic['Stance'].apply(lambda x: 
                                                             2 if x == "FAVOR" else 
                                                             (1 if x == "NONE" else 0)))
  
    #### MODEL ####
    print(topic_in)
    # Train SVM
    start_time_train = time.time()
    svm = SVC(kernel = 'linear', probability = True)
    svm.fit(train_grams, train_stance_labels)
    end_time_train = time.time()
    print("Training time:",end_time_train - start_time_train)

    # Prediction
    start_time_predict = time.time()
    test_predict = svm.predict(test_grams)
    test_predict_proba = svm.predict_proba(test_grams)
    end_time_predict = time.time()
    print("Prediction time:", end_time_predict - start_time_predict)

    # Results
    results_dict = {}
    results_dict['model'] = svm
    results_dict['full_feature_list'] = full_feature_list
    results_dict['train_labels'] = train_stance_labels
    results_dict['train_names'] = train_topic['Stance']
    results_dict['test_true_labels'] = test_stance_labels
    results_dict['test_true_names'] = test_topic['Stance']
    results_dict['test_predict'] = test_predict
    results_dict['test_predict_proba'] = test_predict_proba
    results_dict['test_predict_proba_true'] = [item[test_stance_labels[i]] for i, item in enumerate(test_predict_proba)]
    
    return results_dict

# %%
# Atheism
atheism_svm = svm_stance(twitter_train, twitter_test, 'Atheism')
standard_output(model_results = atheism_svm)
# Out:
# Atheism
# Training time: 4.74280571937561
# Prediction time: 0.49237751960754395
# F1 Score: 0.5887415123104282
#              precision    recall  f1-score   support
#
#     Against       0.82      0.81      0.82       160
#        None       0.46      0.57      0.51        28
#       Favor       0.48      0.41      0.44        32
#
# avg / total       0.73      0.72      0.72       220
# /home/timspittle/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# Hillary Clinton
hillary_svm = svm_stance(twitter_train, twitter_test, 'Hillary Clinton')
standard_output(model_results = hillary_svm)
# Out:
# Hillary Clinton
# Training time: 8.118888139724731
# Prediction time: 0.9967093467712402
# F1 Score: 0.6252657253787928
#              precision    recall  f1-score   support
#
#     Against       0.72      0.83      0.77       172
#        None       0.67      0.63      0.65        78
#       Favor       0.64      0.36      0.46        45
#
# avg / total       0.70      0.70      0.69       295
# /home/timspittle/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# Legalization of Abortion
abortion_svm = svm_stance(twitter_train, twitter_test, 'Legalization of Abortion')
standard_output(model_results = abortion_svm)
# Out:
# Legalization of Abortion
# Training time: 7.40519118309021
# Prediction time: 0.8274450302124023
# F1 Score: 0.5634475771232924
#              precision    recall  f1-score   support
#
#     Against       0.80      0.68      0.73       189
#        None       0.37      0.58      0.45        45
#       Favor       0.50      0.52      0.51        46
#
# avg / total       0.68      0.64      0.65       280
# /home/timspittle/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# Climate Change is a Real Concern
climatechange_svm = svm_stance(twitter_train, twitter_test, 'Climate Change is a Real Concern')
standard_output(model_results = climatechange_svm)
# Out:
# Climate Change is a Real Concern
# Training time: 2.8077661991119385
# Prediction time: 0.322324275970459
# F1 Score: 0.476855927230047
#              precision    recall  f1-score   support
#
#     Against       0.00      0.00      0.00        11
#        None       0.56      0.57      0.56        35
#       Favor       0.83      0.90      0.87       123
#
# avg / total       0.72      0.78      0.75       169
# /home/timspittle/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/timspittle/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/timspittle/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# Feminist Movement
feminist_svm = svm_stance(twitter_train, twitter_test, 'Feminist Movement')
standard_output(model_results = feminist_svm)
# Out:
# Feminist Movement
# Training time: 7.887798070907593
# Prediction time: 0.9194767475128174
# F1 Score: 0.5527962793667377
#              precision    recall  f1-score   support
#
#     Against       0.77      0.60      0.68       183
#        None       0.47      0.52      0.49        44
#       Favor       0.39      0.64      0.49        58
#
# avg / total       0.65      0.60      0.61       285
# /home/timspittle/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ### ELMO

# %%
def elmo_vectors(x):
    embeddings = elmo(x.tolist(), signature="default", as_dict=True)["elmo"]

    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        sess.run(tf.tables_initializer())
        # return average of ELMo features
        return sess.run(tf.reduce_mean(embeddings,1))

# %%
list_train = [twitter_train['Tweet'][i:i+100] for i in range(0,twitter_train['Tweet'].shape[0],100)]
list_test = [twitter_test['Tweet'][i:i+100] for i in range(0,twitter_test['Tweet'].shape[0],100)]

# %%
# elmo_train = [elmo_vectors(x) for x in list_train]
# elmo_test = [elmo_vectors(x) for x in list_test]

# %%
# def svm_elmo(train, test, topic_in):
#     # Subset data to topic being tested
#     train_topic = train[train['Target'] == topic_in]
#     test_topic = test[test['Target'] == topic_in]
    
#     #### FEATURES ####
#     # Extract tweets
#     tweets_train = train_topic['Tweet']
#     tweets_test = test_topic['Tweet']

#     # Pre-process tweets
#     preprocess_train = tweets_train.apply(lambda x: preprocess_tweets(x))
#     preprocess_test = tweets_test.apply(lambda x: preprocess_tweets(x))
    
#     # Convert training data to sparse matrix 
#     # n-gram WORDS
#     word_grams = CountVectorizer(ngram_range = (1,3))
#     train_nwords = word_grams.fit_transform(preprocess_train)
#     test_nwords = word_grams.transform(preprocess_test)
#     word_grams_feature_list = word_grams.get_feature_names()
#     # n-gram CHARS
#     char_grams = CountVectorizer(ngram_range = (2,5), analyzer = 'char')
#     train_nchars = char_grams.fit_transform(preprocess_train)
#     test_nchars = char_grams.transform(preprocess_test)
#     char_grams_feature_list = char_grams.get_feature_names()
    
#     # Stack the features
#     train_grams = hstack((train_nwords, train_nchars))
#     test_grams = hstack((test_nwords, test_nchars))
#     full_feature_list = word_grams_feature_list + char_grams_feature_list
       
#     #### TARGET ####
#     # Convert stance to labels for feeding sklearn SVM
#     train_stance_labels = np.array(train_topic['Stance'].apply(lambda x: 
#                                                                2 if x == "FAVOR" else 
#                                                                (1 if x == "NONE" else 0)))
#     test_stance_labels = np.array(test_topic['Stance'].apply(lambda x: 
#                                                              2 if x == "FAVOR" else 
#                                                              (1 if x == "NONE" else 0)))
  
#     #### MODEL ####
#     print(topic_in)
#     # Train SVM
#     start_time_train = time.time()
#     svm = SVC(kernel = 'linear', probability = True)
#     svm.fit(train_grams, train_stance_labels)
#     end_time_train = time.time()
#     print("Training time:",end_time_train - start_time_train)

#     # Prediction
#     start_time_predict = time.time()
#     test_predict = svm.predict(test_grams)
#     test_predict_proba = svm.predict_proba(test_grams)
#     end_time_predict = time.time()
#     print("Prediction time:", end_time_predict - start_time_predict)

#     # Results
#     results_dict = {}
#     results_dict['model'] = svm
#     results_dict['full_feature_list'] = full_feature_list
#     results_dict['test_true_labels'] = test_stance_labels
#     results_dict['test_true_names'] = test_topic['Stance']
#     results_dict['test_predict'] = test_predict
#     results_dict['test_predict_proba'] = test_predict_proba
#     results_dict['test_predict_proba_true'] = [item[test_stance_labels[i]] for i, item in enumerate(test_predict_proba)]
    
#     return results_dict

# %% [markdown]
# ## Extra - Features

# %%
def top_features_by_label(coef_matrix_in, target_names_in, feature_list_in):
    top_index_lists = []
    top_features_lists = []
    
    # Loop through each label in the coefficient matrix and identify the top 5 features
    for loop_labels in range(coef_matrix_in.shape[0]):
        top_5_index = np.argsort(coef_matrix_in[loop_labels])[::-1][:5]
        top_5_features = [feature_list_in[i] for i in top_5_index]

        top_index_lists.append(top_5_index)
        top_features_lists.append(top_5_features)

    # Flatten feature lists 
    full_top_index_list = [item for sublist in top_index_lists for item in sublist]
    full_top_features_list = [item for sublist in top_features_lists for item in sublist]

    # Creat 20x4 labelled table from coefficeint matrix
    top_20_index = pd.DataFrame(data = coef_matrix_in[:,full_top_index_list].transpose(), \
                                columns = target_names_in, index = full_top_features_list)
    # Plot resulting table
    fig, ax = plt.subplots(figsize = (10,10))
    seaborn.heatmap(top_20_index, annot = True)

# %%
# Top Features
top_features_by_label(coef_matrix_in = atheism_svm['model'].coef_.toarray(), 
                      target_names_in = ['Against', 'None', 'Favor'], 
                      feature_list_in = atheism_svm['full_feature_list'])

# %%
[name for name in atheism_svm['full_feature_list'] if 'god' in name]
# Out:
# ['about god',
#  'about god gods',
#  'absence of god',
#  'according to gods',
#  'accountability god',
#  'accountability god semst',
#  'achievers godfirst',
#  'achievers godfirst actorslife',
#  'activates god',
#  'activates god fear',
#  'after you god',
#  'again bible god',
#  'all powerful god',
#  'almighty god',
#  'almighty god almighty',
#  'almighty god for',
#  'almighty god thats',
#  'amen god',
#  'amen god semst',
#  'and god',
#  'and god loves',
#  'and god will',
#  'and let god',
#  'angels of god',
#  'another god',
#  'another god freethinker',
#  'any god',
#  'any god is',
#  'appreciate almighty god',
#  'at digit god',
#  'awesome life god',
#  'because god',
#  'because god made',
#  'become god',
#  'become god athanasius',
#  'believe god',
#  'believe god supported',
#  'believe in god',
#  'believe that god',
#  'bible god',
#  'bible god semst',
#  'bible god tcot',
#  'bibleverses god',
#  'bibleverses god christianity',
#  'bless almighty god',
#  'both gods',
#  'both gods and',
#  'busy but god',
#  'but god',
#  'but god always',
#  'but god does',
#  'but god is',
#  'but god will',
#  'but nope god',
#  'but the god',
#  'butgod',
#  'butgod semst',
#  'by god',
#  'by god godsnotdead',
#  'by gods',
#  'by gods and',
#  'childofgod',
#  'childofgod semst',
#  'children of god',
#  'church god',
#  'church god pray',
#  'coming god',
#  'coming god semst',
#  'connection to god',
#  'conqueror god',
#  'conqueror god semst',
#  'control god',
#  'control god spiritual',
#  'cruel god',
#  'cruel god makes',
#  'day god',
#  'day god full',
#  'day only god',
#  'day question gods',
#  'days grow god',
#  'denied god',
#  'denied god your',
#  'depended on god',
#  'desire god',
#  'desire god truth',
#  'digit bible god',
#  'digit god',
#  'digit god bible',
#  'digit god bless',
#  'digit god semst',
#  'digit godfearing',
#  'digit godfearing bible',
#  'digitjohn digit god',
#  'do gods',
#  'do gods will',
#  'dont desire god',
#  'dummy his god',
#  'earth god',
#  'earth god christians',
#  'end childofgod',
#  'end childofgod semst',
#  'everything in gods',
#  'exist without god',
#  'facing but god',
#  'faith activates god',
#  'faith togodbetheglory',
#  'faith togodbetheglory semst',
#  'faithful god',
#  'faithful god we',
#  'fearless conqueror god',
#  'find faith togodbetheglory',
#  'find god',
#  'find god sit',
#  'for any god',
#  'for god',
#  'for god do',
#  'for godlove',
#  'for godlove then',
#  'for the god',
#  'for their god',
#  'from achievers godfirst',
#  'fundamentia bibleverses god',
#  'go and god',
#  'god',
#  'god allows',
#  'god allows me',
#  'god almighty',
#  'god almighty holy',
#  'god always',
#  'god always has',
#  'god and',
#  'god and be',
#  'god and focus',
#  'god and jesus',
#  'god and let',
#  'god at',
#  'god at your',
#  'god athanasius',
#  'god athanasius semst',
#  'god attacked',
#  'god attacked by',
#  'god became',
#  'god became man',
#  'god because',
#  'god because you',
#  'god belief',
#  'god belief christianity',
#  'god believe',
#  'god believe he',
#  'god bible',
#  'god bible semst',
#  'god bless',
#  'god bless canada',
#  'god bless you',
#  'god blessed',
#  'god blessed you',
#  'god can',
#  'god can judge',
#  'god can turn',
#  'god cares',
#  'god cares about',
#  'god christianity',
#  'god christianity semst',
#  'god christianlibertarian',
#  'god christianlibertarian semst',
#  'god christians',
#  'god christians christianity',
#  'god could',
#  'god could be',
#  'god decides',
#  'god decides to',
#  'god didnt',
#  'god didnt call',
#  'god digit',
#  'god digit semst',
#  'god do',
#  'god do everything',
#  'god do you',
#  'god does',
#  'god does and',
#  'god doing',
#  'god doing that',
#  'god ensures',
#  'god ensures justice',
#  'god fear',
#  'god fear activates',
#  'god fiction',
#  'god fiction is',
#  'god for',
#  'god for he',
#  'god for my',
#  'god for waking',
#  'god forever',
#  'god forever and',
#  'god freethinker',
#  'god freethinker semst',
#  'god fuck',
#  'god fuck you',
#  'god full',
#  'god full of',
#  'god gave',
#  'god gave us',
#  'god gods',
#  'god gods not',
#  'god godsnotdead',
#  'god godsnotdead truth',
#  'god has',
#  'god has better',
#  'god has given',
#  'god has not',
#  'god has placed',
#  'god has wonderful',
#  'god he',
#  'god he will',
#  'god here',
#  'god here always',
#  'god hes',
#  'god hes the',
#  'god his',
#  'god his test',
#  'god im',
#  'god im an',
#  'god impossible',
#  'god impossible logic',
#  'god is',
#  'god is always',
#  'god is and',
#  'god is comprehensive',
#  'god is faithful',
#  'god is getting',
#  'god is humble',
#  'god is in',
#  'god is really',
#  'god is so',
#  'god is still',
#  'god is superstition',
#  'god is that',
#  'god islam',
#  'god islam semst',
#  'god isnt',
#  'god isnt as',
#  'god it',
#  'god it just',
#  'god joseph',
#  'god joseph smith',
#  'god lost',
#  'god lost love',
#  'god love',
#  'god love hope',
#  'god loves',
#  'god loves me',
#  'god loves the',
#  'god loving',
#  'god loving eo',
#  'god loving is',
#  'god loving one',
#  'god made',
#  'god made it',
#  'god makes',
#  'god makes cruel',
#  'god matthew',
#  'god matthew digit',
#  'god miraculous',
#  'god miraculous and',
#  'god named',
#  'god named god',
#  'god never',
#  'god never gives',
#  'god of',
#  'god of my',
#  'god of the',
#  'god on',
#  'god on the',
#  'god please',
#  'god please leave',
#  'god pray',
#  'god pray for',
#  'god pray semst',
#  'god pray that',
#  'god proclaiming',
#  'god proclaiming our',
#  'god put',
#  'god put period',
#  'god rejoices',
#  'god rejoices when',
#  'god semst',
#  'god sit',
#  'god sit downbreathe',
#  'god spiritual',
#  'god spiritual motivation',
#  'god still',
#  'god still and',
#  'god supported',
#  'god supported slavery',
#  'god supported their',
#  'god talk',
#  'god talk in',
#  'god tcot',
#  'god tcot pdigit',
#  'god teamjesus',
#  'god teamjesus semst',
#  'god that',
#  'god that he',
#  'god thats',
#  'god thats just',
#  'god there',
#  'god there will',
#  'god time',
#  'god time to',
#  'god to',
#  'god to guide',
#  'god to remember',
#  'god truth',
#  'god truth love',
#  'god unknown',
#  'god unknown quote',
#  'god we',
#  'god we also',
#  'god we pray',
#  'god what',
#  'god what are',
#  'god will',
#  'god will never',
#  'god will set',
#  'god will step',
#  'god will trust',
#  'god work',
#  'god work as',
#  'god work semst',
#  'god worship',
#  'god worship fuckreligion',
#  'god wouldnt',
#  'god wouldnt invest',
#  'god your',
#  'god your soul',
#  'god yours',
#  'god yours not',
#  'godfearing',
#  'godfearing bible',
#  'godfearing bible believing',
#  'godfirst',
#  'godfirst actorslife',
#  'godfirst actorslife dancer',
#  'godisgood',
#  'godisgood semst',
#  'godlessgala',
#  'godlessgala semst',
#  'godlove',
#  'godlove then',
#  'godlove then you',
#  'gods',
#  'gods and',
#  'gods and angels',
#  'gods and religion',
#  'gods before',
#  'gods before me',
#  'gods hand',
#  'gods hand is',
#  'gods hand rest',
#  'gods law',
#  'gods law keep',
#  'gods not',
#  'gods not testing',
#  'gods playing',
#  'gods playing along',
#  'gods presence',
#  'gods presence the',
#  'gods will',
#  'gods will in',
#  'gods word',
#  'gods word it',
#  'gods word yields',
#  'gods work',
#  'gods work and',
#  'godsnotdead',
#  'godsnotdead truth',
#  'godsnotdead truth semst',
#  'godwillhear',
#  'godwillhear me',
#  'godwillhear me micah',
#  'goldanuli god',
#  'goldanuli god isnt',
#  'good day god',
#  'gregabbotttx which god',
#  'grow god',
#  'grow god still',
#  'hand of god',
#  'hands of god',
#  'having about god',
#  'hebrewsdigitnlt god',
#  'hebrewsdigitnlt god semst',
#  'help me god',
#  'his god',
#  'his god bless',
#  'hope butgod',
#  'hope butgod semst',
#  'house of god',
#  'how gods',
#  'how gods playing',
#  'iamisthepotter god',
#  'iamisthepotter god belief',
#  'iamtheclay iamisthepotter god',
#  'if god',
#  'if god miraculous',
#  'if theres god',
#  'impossible god',
#  'impossible god semst',
#  'impossible then god',
#  'in control god',
#  'in cruel god',
#  'in end childofgod',
#  'in god',
#  'in god at',
#  'in god attacked',
#  'in god it',
#  'in god please',
#  'in gods',
#  'in gods hand',
#  'in gods presence',
#  'in gods word',
#  'in vain god',
#  'innocent may god',
#  'insanity of god',
#  'intrigued by gods',
#  'is coming god',
#  'is how gods',
#  'is love god',
#  'is pleasing god',
#  'ispeaklife god',
#  'ispeaklife god digit',
#  'john digit god',
#  'judged by god',
#  'just another god',
#  'just trust god',
#  'know that god',
#  'know that gods',
#  'know who god',
#  'lamb of god',
#  'let god',
#  'let god work',
#  'life god',
#  'life god has',
#  'like our god',
#  'look to god',
#  'lost god',
#  'lost god lost',
#  'love amen god',
#  'love god',
#  'love god love',
#  'make believe god',
#  'man of god',
#  'mark where god',
#  'may god',
#  'may god bless',
#  'me god',
#  'me god to',
#  'me want god',
#  'men accountability god',
#  'mercy of god',
#  'might become god',
#  'milkexodusdigit thank god',
#  'mind denied god',
#  'mind ispeaklife god',
#  'moments god',
#  'moments god here',
#  'monster or god',
#  'mother of god',
#  'much my god',
#  'my god',
#  'my god is',
#  'my god loves',
#  'my godwillhear',
#  'my godwillhear me',
#  'name hebrewsdigitnlt god',
#  'name of god',
#  'named god',
#  'named god is',
#  'need for godlove',
#  'no god',
#  'no god loving',
#  'no other gods',
#  'nope god',
#  'nope god semst',
#  'not pleasing god',
#  'nothing for god',
#  'of god',
#  'of god became',
#  'of god for',
#  'of god forever',
#  'of god he',
#  'of god is',
#  'of god joseph',
#  'of god matthew',
#  'of god pray',
#  'of god semst',
#  'of god that',
#  'of god unknown',
#  'of god we',
#  'of god what',
#  'of god will',
#  'of god worship',
#  'of gods',
#  'of gods word',
#  'on god',
#  'on god believe',
#  'on god work',
#  'only god',
#  'only god can',
#  'only true god',
#  'or god',
#  'or god semst',
#  'other gods',
#  'other gods before',
#  'our god',
#  'our god hes',
#  'papa god',
#  'papa god pray',
#  'people god',
#  'people god has',
#  'plan of god',
#  'plan trust godisgood',
#  'planned god',
#  'planned god has',
#  'pleasing god',
#  'pleasing god his',
#  'pleasing god there',
#  'powerful god',
#  'powerful god time',
#  'praise to god',
#  'question gods',
#  'question gods work',
#  'quits on god',
#  'rosary god',
#  'rosary god teamjesus',
#  'rosary teamjesus god',
#  'rt goldanuli god',
#  'sacredcows thinkingatheist godlessgala',
#  'salvation my godwillhear',
#  'shout almighty god',
#  'sometimes god',
#  'sometimes god could',
#  'son of god',
#  'stand with god',
#  'stop what god',
#  'teamjesus god',
#  'teamjesus god semst',
#  'thank god',
#  'thank god im',
#  'that bible god',
#  'that god',
#  'that god is',
#  'that gods',
#  'that gods hand',
#  'that under god',
#  'thats when god',
#  'the digit godfearing',
#  'the earth god',
#  'the god',
#  'the god named',
#  'the god of',
#  'the god talk',
#  'the impossible god',
#  'the people god',
#  'the workload god',
#  'their god',
#  'their god do',
#  'then god',
#  'then god impossible',
#  'theres god',
#  'theres god fuck',
#  'theres no god',
#  'thinkingatheist godlessgala',
#  'thinkingatheist godlessgala semst',
#  'time in gods',
#  'tissues church god',
#  'to do gods',
#  'to god',
#  'to god allows',
#  'to god and',
#  'to god proclaiming',
#  'to gods',
#  'to gods law',
#  'to trust god',
#  'today but god',
#  'togodbetheglory',
#  'togodbetheglory semst',
#  'true god',
#  'true god and',
#  'true your god',
#  'trust god',
#  'trust god and',
#  'trust god to',
#  'trust godisgood',
#  'trust godisgood semst',
#  'truth hope butgod',
#  'truth of gods',
#  'under god',
#  'under god on',
#  'us rosary god',
#  'vain god',
#  'vain god semst',
#  'want god',
#  'want god doing',
#  'what god',
#  'what god is',
#  'when god',
#  'when god will',
#  'where god',
#  'where god put',
#  'which god',
#  'which god yours',
#  'who god',
#  'who god is',
#  'widows and god',
#  'will of god',
#  'with god',
#  'with god and',
#  'without god',
#  'without god christianlibertarian',
#  'word of god',
#  'workload god',
#  'workload god decides',
#  'worst moments god',
#  'you but god',
#  'you find god',
#  'you god',
#  'you god islam',
#  'you lost god',
#  'you planned god',
#  'your god',
#  'your god fiction',
#  ' #god',
#  ' god',
#  ' god ',
#  ' godf',
#  ' godl',
#  ' gods',
#  ' godw',
#  '#god',
#  '#god ',
#  '#godf',
#  '#godi',
#  '#godl',
#  '#gods',
#  'a god',
#  'd god',
#  'e god',
#  'f god',
#  'fgod',
#  'fgod ',
#  'g god',
#  'god',
#  'god ',
#  'god #',
#  'god a',
#  'god b',
#  'god c',
#  'god d',
#  'god e',
#  'god f',
#  'god g',
#  'god h',
#  'god i',
#  'god j',
#  'god l',
#  'god m',
#  'god n',
#  'god o',
#  'god p',
#  'god r',
#  'god s',
#  'god t',
#  'god u',
#  'god w',
#  'god y',
#  'godb',
#  'godbe',
#  'godf',
#  'godfe',
#  'godfi',
#  'godi',
#  'godis',
#  'godl',
#  'godle',
#  'godlo',
#  'gods',
#  'gods ',
#  'godsn',
#  'godw',
#  'godwi',
#  'h god',
#  'i god',
#  'k god',
#  'l god',
#  'n god',
#  'o god',
#  'ofgod',
#  'ogod',
#  'ogodb',
#  'r god',
#  's god',
#  't god',
#  'tgod',
#  'tgod ',
#  'togod',
#  'utgod',
#  'w god',
#  'y god']

# %%
top_index_lists = []
top_features_lists = []

# Loop through each label in the coefficient matrix and identify the top 5 features
for loop_labels in range(atheism_svm['model'].coef_.toarray().shape[0]):
    top_5_index = np.argsort(atheism_svm['model'].coef_.toarray()[loop_labels])[::-1][:5]
    top_5_features = [atheism_svm['full_feature_list'][i] for i in top_5_index]

    top_index_lists.append(top_5_index)
    top_features_lists.append(top_5_features)
print(top_features_lists)
# Out:
# [['god', 'go', 'god ', 'god', 'ea'], ['am', ' #', 'or', 'nd', 'i '], [' #', 'or', 're ', 'e ', 'al']]

# %%
[name for name in atheism_svm['full_feature_list'] if '#' in name]
# Out:
# [' #',
#  ' #a',
#  ' #ab',
#  ' #abe',
#  ' #abu',
#  ' #ac',
#  ' #acc',
#  ' #act',
#  ' #ag',
#  ' #agn',
#  ' #al',
#  ' #all',
#  ' #alw',
#  ' #am',
#  ' #ama',
#  ' #ame',
#  ' #an',
#  ' #ant',
#  ' #ap',
#  ' #apd',
#  ' #as',
#  ' #ask',
#  ' #ass',
#  ' #at',
#  ' #ath',
#  ' #atl',
#  ' #au',
#  ' #aut',
#  ' #aw',
#  ' #awa',
#  ' #b',
#  ' #ba',
#  ' #bal',
#  ' #ban',
#  ' #bc',
#  ' #bco',
#  ' #be',
#  ' #bea',
#  ' #bee',
#  ' #bei',
#  ' #bel',
#  ' #bet',
#  ' #bh',
#  ' #bha',
#  ' #bhs',
#  ' #bi',
#  ' #bib',
#  ' #bl',
#  ' #ble',
#  ' #bo',
#  ' #boo',
#  ' #bor',
#  ' #br',
#  ' #bro',
#  ' #bu',
#  ' #bud',
#  ' #but',
#  ' #by',
#  ' #bye',
#  ' #c',
#  ' #ca',
#  ' #cal',
#  ' #cat',
#  ' #cc',
#  ' #cco',
#  ' #cd',
#  ' #cdn',
#  ' #ch',
#  ' #cha',
#  ' #chi',
#  ' #chr',
#  ' #chu',
#  ' #ci',
#  ' #civ',
#  ' #co',
#  ' #coe',
#  ' #com',
#  ' #con',
#  ' #cr',
#  ' #cre',
#  ' #cri',
#  ' #cu',
#  ' #cul',
#  ' #cur',
#  ' #d',
#  ' #da',
#  ' #dan',
#  ' #dar',
#  ' #de',
#  ' #dec',
#  ' #dee',
#  ' #dem',
#  ' #des',
#  ' #dev',
#  ' #di',
#  ' #dig',
#  ' #dis',
#  ' #div',
#  ' #do',
#  ' #don',
#  ' #dr',
#  ' #dre',
#  ' #dro',
#  ' #e',
#  ' #ea',
#  ' #ear',
#  ' #ec',
#  ' #eco',
#  ' #em',
#  ' #emp',
#  ' #en',
#  ' #end',
#  ' #eq',
#  ' #equ',
#  ' #es',
#  ' #est',
#  ' #et',
#  ' #eth',
#  ' #ex',
#  ' #exp',
#  ' #f',
#  ' #fa',
#  ' #fad',
#  ' #fai',
#  ' #fas',
#  ' #fat',
#  ' #fb',
#  ' #fb ',
#  ' #fc',
#  ' #fca',
#  ' #fe',
#  ' #fea',
#  ' #fed',
#  ' #fem',
#  ' #ff',
#  ' #ffr',
#  ' #fi',
#  ' #fig',
#  ' #fl',
#  ' #fla',
#  ' #fo',
#  ' #foc',
#  ' #foo',
#  ' #fr',
#  ' #fre',
#  ' #fri',
#  ' #fs',
#  ' #fsm',
#  ' #ft',
#  ' #fts',
#  ' #fu',
#  ' #fuc',
#  ' #fun',
#  ' #fut',
#  ' #g',
#  ' #ga',
#  ' #gam',
#  ' #gay',
#  ' #ge',
#  ' #gen',
#  ' #get',
#  ' #gf',
#  ' #gfy',
#  ' #gi',
#  ' #giv',
#  ' #gl',
#  ' #gle',
#  ' #go',
#  ' #god',
#  ' #gol',
#  ' #goo',
#  ' #gos',
#  ' #got',
#  ' #gr',
#  ' #gra',
#  ' #gre',
#  ' #gw',
#  ' #gwg',
#  ' #h',
#  ' #ha',
#  ' #hal',
#  ' #hap',
#  ' #he',
#  ' #hea',
#  ' #hel',
#  ' #her',
#  ' #ho',
#  ' #hol',
#  ' #hom',
#  ' #hop',
#  ' #hu',
#  ' #hum',
#  ' #hus',
#  ' #hy',
#  ' #hyp',
#  ' #i',
#  ' #ia',
#  ' #iam',
#  ' #ic',
#  ' #ico',
#  ' #id',
#  ' #ide',
#  ' #im',
#  ' #ima',
#  ' #in',
#  ' #inc',
#  ' #ini',
#  ' #inn',
#  ' #ins',
#  ' #int',
#  ' #inv',
#  ' #ir',
#  ' #ira',
#  ' #ire',
#  ' #iro',
#  ' #is',
#  ' #isl',
#  ' #isp',
#  ' #isr',
#  ' #j',
#  ' #ja',
#  ' #jad',
#  ' #je',
#  ' #jer',
#  ' #jes',
#  ' #jo',
#  ' #joy',
#  ' #ju',
#  ' #jud',
#  ' #jul',
#  ' #jus',
#  ' #k',
#  ' #ke',
#  ' #kee',
#  ' #kh',
#  ' #kho',
#  ' #ki',
#  ' #kin',
#  ' #ku',
#  ' #kuk',
#  ' #kuw',
#  ' #l',
#  ' #la',
#  ' #lal',
#  ' #lay',
#  ' #laz',
#  ' #le',
#  ' #lea',
#  ' #leb',
#  ' #let',
#  ' #lg',
#  ' #lgb',
#  ' #li',
#  ' #lib',
#  ' #lif',
#  ' #liv',
#  ' #lo',
#  ' #log',
#  ' #lol',
#  ' #lor',
#  ' #lov',
#  ' #ly',
#  ' #lyi',
#  ' #lyr',
#  ' #m',
#  ' #ma',
#  ' #mag',
#  ' #mar',
#  ' #mat',
#  ' #me',
#  ' #me ',
#  ' #mea',
#  ' #men',
#  ' #mer',
#  ' #mex',
#  ' #mi',
#  ' #mia',
#  ' #min',
#  ' #mis',
#  ' #mo',
#  ' #mor',
#  ' #mot',
#  ' #mu',
#  ' #mus',
#  ' #n',
#  ' #na',
#  ' #nar',
#  ' #ne',
#  ' #nee',
#  ' #new',
#  ' #nex',
#  ' #no',
#  ' #nod',
#  ' #non',
#  ' #nor',
#  ' #now',
#  ' #o',
#  ' #ob',
#  ' #obs',
#  ' #on',
#  ' #one',
#  ' #op',
#  ' #opp',
#  ' #opt',
#  ' #p',
#  ' #pa',
#  ' #par',
#  ' #pd',
#  ' #pdi',
#  ' #pe',
#  ' #pea',
#  ' #ph',
#  ' #phn',
#  ' #pj',
#  ' #pjn',
#  ' #pk',
#  ' #pk ',
#  ' #po',
#  ' #pol',
#  ' #poo',
#  ' #pos',
#  ' #pot',
#  ' #pow',
#  ' #pr',
#  ' #pra',
#  ' #pre',
#  ' #pri',
#  ' #pro',
#  ' #ps',
#  ' #psa',
#  ' #pu',
#  ' #pur',
#  ' #q',
#  ' #qu',
#  ' #quo',
#  ' #qur',
#  ' #r',
#  ' #ra',
#  ' #rac',
#  ' #ram',
#  ' #rat',
#  ' #re',
#  ' #rea',
#  ' #rel',
#  ' #rem',
#  ' #rep',
#  ' #res',
#  ' #rev',
#  ' #ro',
#  ' #roa',
#  ' #ros',
#  ' #rt',
#  ' #rt ',
#  ' #ru',
#  ' #rul',
#  ' #rus',
#  ' #rw',
#  ' #rwa',
#  ' #s',
#  ' #sa',
#  ' #sac',
#  ' #saf',
#  ' #sah',
#  ' #sal',
#  ' #say',
#  ' #sb',
#  ' #sbd',
#  ' #sc',
#  ' #sca',
#  ' #scf',
#  ' #sch',
#  ' #sci',
#  ' #sco',
#  ' #scr',
#  ' #se',
#  ' #see',
#  ' #sem',
#  ' #sep',
#  ' #ser',
#  ' #sex',
#  ' #sh',
#  ' #sha',
#  ' #she',
#  ' #shi',
#  ' #sho',
#  ' #shu',
#  ' #si',
#  ' #sig',
#  ' #sim',
#  ' #sin',
#  ' #sk',
#  ' #ske',
#  ' #so',
#  ' #soc',
#  ' #sol',
#  ' #son',
#  ' #sot',
#  ' #sp',
#  ' #spi',
#  ' #st',
#  ' #ste',
#  ' #stl',
#  ' #str',
#  ' #su',
#  ' #sun',
#  ' #sup',
#  ' #sy',
#  ' #syf',
#  ' #t',
#  ' #ta',
#  ' #tab',
#  ' #tc',
#  ' #tco',
#  ' #te',
#  ' #tea',
#  ' #tem',
#  ' #ter',
#  ' #th',
#  ' #tha',
#  ' #the',
#  ' #thi',
#  ' #tho',
#  ' #ti',
#  ' #tin',
#  ' #to',
#  ' #tog',
#  ' #tol',
#  ' #tr',
#  ' #tre',
#  ' #tru',
#  ' #tu',
#  ' #tun',
#  ' #u',
#  ' #um',
#  ' #umm',
#  ' #un',
#  ' #und',
#  ' #uni',
#  ' #unt',
#  ' #us',
#  ' #us ',
#  ' #usa',
#  ' #use',
#  ' #v',
#  ' #va',
#  ' #van',
#  ' #vat',
#  ' #vi',
#  ' #vis',
#  ' #w',
#  ' #wa',
#  ' #wak',
#  ' #war',
#  ' #wat',
#  ' #we',
#  ' #wee',
#  ' #wew',
#  ' #wh',
#  ' #who',
#  ' #wi',
#  ' #wil',
#  ' #wis',
#  ' #wo',
#  ' #wor',
#  ' #y',
#  ' #ye',
#  ' #yes',
#  ' #yo',
#  ' #you',
#  ' a #',
#  ' a #s',
#  ' an #',
#  ' as #',
#  ' at #',
#  ' be #',
#  ' do #',
#  ' in #',
#  ' is #',
#  ' it #',
#  ' me #',
#  ' my #',
#  ' no #',
#  ' of #',
#  ' ok #',
#  ' on #',
#  ' s #',
#  ' s #s',
#  ' to #',
#  ' up #',
#  ' us #',
#  ' w #',
#  ' w #s',
#  ' we #',
#  ' wow#',
#  ' you#',
#  '#a',
#  '#ab',
#  '#abe',
#  '#abed',
#  '#abu',
#  '#abun',
#  '#ac',
#  '#acc',
#  '#acce',
#  '#acco',
#  '#act',
#  '#acto',
#  '#ag',
#  '#agn',
#  '#agno',
#  '#al',
#  '#all',
#  '#alla',
#  '#alw',
#  '#alwa',
#  '#am',
#  '#ama',
#  '#ama ',
#  '#ame',
#  '#amer',
#  '#an',
#  '#ant',
#  '#anti',
#  '#ap',
#  '#apd',
#  '#apdi',
#  '#as',
#  '#ask',
#  '#aska',
#  '#askb',
#  '#ass',
#  '#assu',
#  '#at',
#  '#ath',
#  '#athe',
#  '#athi',
#  '#atl',
#  '#atlp',
#  '#au',
#  '#aut',
#  '#auth',
#  '#aw',
#  '#awa',
#  '#awar',
#  '#b',
#  '#ba',
#  '#bal',
#  '#balt',
#  '#ban',
#  '#band',
#  '#bank',
#  '#bc',
#  '#bco',
#  '#bcot',
#  '#be',
#  '#bea',
#  '#beag',
#  '#bee',
#  '#beer',
#  '#bei',
#  '#bein',
#  '#bel',
#  '#beli',
#  '#bet',
#  '#beth',
#  '#bh',
#  '#bha',
#  '#bhad',
#  '#bhar',
#  '#bhs',
#  '#bhsv',
#  '#bi',
#  '#bib',
#  '#bibl',
#  '#bl',
#  '#ble',
#  '#bles',
#  '#bo',
#  '#boo',
#  '#boom',
#  '#bor',
#  '#born',
#  '#br',
#  '#bro',
#  '#brot',
#  '#bu',
#  '#bud',
#  '#budd',
#  '#but',
#  '#butg',
#  '#by',
#  '#bye',
#  '#bye ',
#  '#c',
#  '#ca',
#  '#cal',
#  '#call',
#  '#cat',
#  '#cath',
#  '#cc',
#  '#cco',
#  '#ccot',
#  '#cd',
#  '#cdn',
#  '#cdnp',
#  '#ch',
#  '#cha',
#  '#chap',
#  '#chi',
#  '#chic',
#  '#chil',
#  '#chr',
#  '#chri',
#  '#chu',
#  '#chur',
#  '#ci',
#  '#civ',
#  '#civi',
#  '#co',
#  '#coe',
#  '#coex',
#  '#col',
#  '#colu',
#  '#com',
#  '#come',
#  '#comm',
#  '#con',
#  '#conf',
#  '#conq',
#  '#cons',
#  '#cr',
#  '#cre',
#  '#crea',
#  '#cri',
#  '#crit',
#  '#cu',
#  '#cul',
#  '#cult',
#  '#cur',
#  '#curr',
#  '#d',
#  '#da',
#  '#dan',
#  '#danc',
#  '#dar',
#  '#dark',
#  '#de',
#  '#dec',
#  '#dece',
#  '#dee',
#  '#deen',
#  '#dem',
#  '#demo',
#  '#des',
#  '#dest',
#  '#dev',
#  '#deva',
#  '#di',
#  '#dig',
#  '#digi',
#  '#dis',
#  '#disc',
#  '#div',
#  '#dive',
#  '#do',
#  '#don',
#  '#dont',
#  '#dr',
#  '#dre',
#  '#drea',
#  '#dro',
#  '#drou',
#  '#e',
#  '#ea',
#  '#ear',
#  '#eart',
#  '#ec',
#  '#eco',
#  '#econ',
#  '#em',
#  '#emp',
#  '#empi',
#  '#en',
#  '#end',
#  '#endr',
#  '#eq',
#  '#equ',
#  '#equa',
#  '#es',
#  '#est',
#  '#este',
#  '#et',
#  '#eth',
#  '#ethi',
#  '#ex',
#  '#exp',
#  '#expo',
#  '#f',
#  '#fa',
#  '#fad',
#  '#fads',
#  '#fai',
#  '#fair',
#  '#fait',
#  '#fas',
#  '#fash',
#  '#fat',
#  '#fath',
#  '#fb',
#  '#fb ',
#  '#fb #',
#  '#fc',
#  '#fca',
#  '#fca ',
#  '#fe',
#  '#fea',
#  '#fear',
#  '#fed',
#  '#fede',
#  '#fem',
#  '#femi',
#  '#ff',
#  '#ffr',
#  '#ffrf',
#  '#fi',
#  '#fig',
#  '#figh',
#  '#fl',
#  '#fla',
#  '#flas',
#  '#fo',
#  '#foc',
#  '#focu',
#  '#foo',
#  '#food',
#  '#for',
#  '#fore',
#  '#fr',
#  '#fre',
#  '#free',
#  '#fri',
#  '#frie',
#  '#fs',
#  '#fsm',
#  '#fsm ',
#  '#ft',
#  '#fts',
#  '#ftsa',
#  '#fu',
#  '#fuc',
#  '#fuck',
#  '#fun',
#  '#fund',
#  '#funn',
#  '#fut',
#  '#futu',
#  '#g',
#  '#ga',
#  '#gam',
#  '#game',
#  '#gay',
#  '#gay ',
#  '#ge',
#  '#gen',
#  '#gend',
#  '#get',
#  '#gett',
#  '#gf',
#  '#gfy',
#  '#gfyh',
#  '#gi',
#  '#giv',
#  '#givi',
#  '#gl',
#  '#gle',
#  '#glen',
#  '#go',
#  '#god',
#  '#god ',
#  '#godf',
#  '#godi',
#  '#godl',
#  '#gods',
#  '#gol',
#  '#gold',
#  '#goo',
#  '#good',
#  '#gos',
#  '#gosl',
#  '#gosp',
#  '#got',
#  '#gotf',
#  '#gr',
#  '#gra',
#  '#grac',
#  '#gre',
#  '#gree',
#  '#gw',
#  '#gwg',
#  '#gwg ',
#  '#h',
#  '#ha',
#  '#had',
#  '#hadi',
#  '#hal',
#  '#hall',
#  '#hap',
#  '#happ',
#  '#he',
#  '#hea',
#  '#heal',
#  '#hel',
#  '#heli',
#  '#help',
#  '#her',
#  '#here',
#  '#hero',
#  '#ho',
#  '#hol',
#  '#holy',
#  '#hom',
#  '#home',
#  '#homo',
#  '#hop',
#  '#hope',
#  '#hu',
#  '#hum',
#  '#huma',
#  '#humb',
#  '#hus',
#  '#hust',
#  '#hy',
#  '#hyp',
#  '#hypo',
#  '#i',
#  '#ia',
#  '#iam',
#  '#iami',
#  '#iamt',
#  '#ib',
#  '#ibr',
#  '#ibra',
#  '#ic',
#  '#ico',
#  '#icou',
#  '#id',
#  '#ide',
#  '#iden',
#  '#im',
#  '#ima',
#  '#imag',
#  '#in',
#  '#inc',
#  '#incl',
#  '#ind',
#  '#indi',
#  '#ini',
#  '#init',
#  '#inn',
#  '#inno',
#  '#ins',
#  '#insp',
#  '#int',
#  '#inte',
#  '#inv',
#  '#inv ',
#  '#ir',
#  '#ira',
#  '#iran',
#  '#ire',
#  '#irel',
#  '#iro',
#  '#iron',
#  '#is',
#  '#isl',
#  '#isla',
#  '#isp',
#  '#ispe',
#  '#isr',
#  '#isra',
#  '#j',
#  '#ja',
#  '#jad',
#  '#jade',
#  '#je',
#  '#jer',
#  '#jere',
#  '#jes',
#  '#jesu',
#  '#jo',
#  '#joy',
#  '#joy ',
#  '#ju',
#  '#jud',
#  '#juda',
#  '#jul',
#  '#july',
#  '#jus',
#  '#just',
#  '#k',
#  '#ke',
#  '#kee',
#  '#keep',
#  '#kh',
#  '#kho',
#  '#khol',
#  '#ki',
#  '#kin',
#  '#king',
#  '#ku',
#  '#kuk',
#  '#kukk',
#  '#kuw',
#  '#kuwa',
#  '#l',
#  '#la',
#  '#lal',
#  '#lali',
#  '#lay',
#  '#laym',
#  '#laz',
#  '#lazy',
#  '#le',
#  '#lea',
#  '#lead',
#  '#leb',
#  '#leba',
#  '#let',
#  '#leth',
#  '#lets',
#  '#lg',
#  '#lgb',
#  '#lgbt',
#  '#li',
#  '#lib',
#  '#libe',
#  '#lif',
#  '#life',
#  '#liv',
#  '#live',
#  '#lo',
#  '#log',
#  '#logi',
#  '#lol',
#  '#lol ',
#  '#lor',
#  '#lord',
#  '#lov',
#  '#love',
#  '#ly',
#  '#lyi',
#  '#lyin',
#  '#lyr',
#  '#lyri',
#  '#m',
#  '#ma',
#  '#mag',
#  '#magn',
#  '#mar',
#  '#marr',
#  '#mary',
#  '#mat',
#  '#mate',
#  '#me',
#  '#me ',
#  '#me #',
#  '#mea',
#  '#mean',
#  '#men',
#  '#men ',
#  '#mer',
#  '#merc',
#  '#mex',
#  '#mexi',
#  '#mi',
#  '#mia',
#  '#miam',
#  '#min',
#  '#mino',
#  '#mis',
#  '#miss',
#  '#mo',
#  '#mor',
#  '#morm',
#  '#mot',
#  '#moti',
#  '#mu',
#  '#mus',
#  '#musl',
#  '#n',
#  '#na',
#  '#nar',
#  '#narw',
#  '#ne',
#  '#nec',
#  '#nece',
#  '#nee',
#  '#need',
#  '#new',
#  '#news',
#  ...]
